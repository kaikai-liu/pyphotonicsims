# %%
# These two lines allow for the notebook to automatically update to use the most
# up-to-date versions of the code being imported
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt
from pyphotonicsims.components.elements import *
from pyphotonicsims.box_integration import get_box_path
import h5py

# plt.style.available
# %matplotlib inline
plt.style.use('science')
plt.rcParams['text.usetex'] = False
plt.rcParams['figure.figsize'] = [4,3]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Directional coupler
#  - Coupling power
#  $$\kappa = \sin{\frac{\pi \delta n L_c}{\lambda}}$$
#  - Coupling rate for resonator
#  $$\gamma_{ex} = \frac{c\log{1/(1-\kappa^2)}}{n_g L}$$

# %%
dn = 0.001
L = 1.0
ng = 1.53
wl = 1550e-9
Lc = np.linspace(0, 3e-3, 100)
ka2 = directional_coupler(dn, Lc, wl)
r_ex = cavity_coupling_rate(ka2, ng, L)/(2*np.pi*1e6)

plt.figure()
plt.plot(Lc*1e3, ka2)
plt.xlabel(r'L$_c$ (mm)')
plt.ylabel(r'$\kappa^2$')

plt.figure()
plt.plot(Lc*1e3, r_ex)
plt.xlabel(r'L$_c$ (mm)')
plt.ylabel(r'$\gamma_{ex}/2\pi$ (MHz)')
plt.ylim((0, 10))
# Out:
# (0.0, 10.0)

# %% [markdown]
# ### 1550 nm 6 $\mu$m by 80 nm waveguide coupling $\delta n_{eff} $simulations

# %%
filename = 'coupling_data_6umby80nm_gap_2_5um_sweep_wl_750_to_1650.mat'
filepath = 'C:\\Users\\HUAWEI\\Box\\Simulations\\lumerical mode\\coupler\\6um by 80nm waveguide\\' + filename
f = h5py.File(filepath, 'r')

dneff = f['dneff'][:].T
wl_coupling = f['wl_list'][:][0]

ng = 1.53
Lx = 1e-3
L = 4.0
mode_ind = 0 # for TE0

ka2 = directional_coupler(dneff[:, mode_ind], Lx, wl_coupling)
kam = 4*ka2*(1-ka2)
r_ex_1 = cavity_coupling_rate(ka2, ng, L)/(2*np.pi*1e6)
r_ex_2 = cavity_coupling_rate(kam, ng, L)/(2*np.pi*1e6)

# plot
plt.semilogy(wl_list, r_list[1, :], 'o', label = 'Intrinsic')
plt.semilogy(wl_list, r_list[0, :], 'x', label = 'Coupling')
plt.semilogy(wl_coupling*1e9, r_ex_1, '--', label = 'Simulated 1-p')
# plt.semilogy(wl_coupling*1e9, r_ex_2, '--', label = 'Simulated 2-p')

plt.xlim([1350, 1650])
plt.ylim([0.04, 4.5])
plt.xlabel(r'Wavelength $\lambda$ (nm)')
plt.ylabel('Resonator linewidth (MHz)')
plt.legend(loc='lower right')

# %%
base_path = 'Simulations/lumerical mode/coupler/6um by 80nm waveguide'
filename = 'coupling_data_6umby80nm_gap_2_5um_sweep_wl_750_to_1650.mat'
filepath = get_box_path(base_path, filename)
f = h5py.File(filepath, 'r')
dneff = f['dneff'][:]
wl_list = f['wl_list'][:][0]
dneff.shape
# Out:
# (6, 46)

# %% [markdown]
# ### (1.1) Evaluate $\kappa^2$ by sweeping Lx at gap 2.5 $\mu$m
#  - 2-point-coupled 4 meter coil resonator (COIL_V4) measures a maximum coupling of 6 MHz
#  - Coupling power $$\kappa_m^2 = 4\kappa^2(1-\kappa^2)$$

# %%
wl = 1550e-9
ng = 1.53
Lx = 1e-3
L = 4.0

WG_mode_dir = {'TE0': 0, 'TE1': 1, 'TE2': 2, 'TM0': 3}
mode_list = ['TE0', 'TE1', 'TE2', 'TM0']
mode_ind = [WG_mode_dir[mode] for mode in mode_list]

ka2 = np.array([directional_coupler(dneff[ii, :], Lx, wl_list) for ii in mode_ind])
# kam = 4*ka2*(1-ka2)
r_ex = cavity_coupling_rate(ka2, ng, L)/(2*np.pi*1e6)

plt.figure()
plt.semilogy(wl_list*1e9, ka2.T)
plt.xlabel(r'$lambda$ (nm)')
plt.ylabel(r'$\kappa^2$')
plt.legend(mode_list)

plt.figure()
plt.semilogy(wl_list*1e9, r_ex.T)
plt.xlabel(r'$lambda$ (nm)')
plt.ylabel(r'$\gamma_{ex}/2\pi$ (MHz)')
plt.legend(mode_list)
plt.ylim(1e-3, 20)
# Out:
# (0.001, 20)
